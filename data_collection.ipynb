# %%
from youtube_comment_downloader import YoutubeCommentDownloader

def scrap_youtube_comments(video_urls):
    downloader = YoutubeCommentDownloader()

    all_comments = []

    for video_url in video_urls:
        if "youtu.be/" in video_url:
            video_id = video_url.split("youtu.be/")[1].split("?")[0]
        elif "youtube.com/watch?v=" in video_url:
            video_id = video_url.split("v=")[1].split("&")[0]
        else:
            raise ValueError(f"Invalid YouTube URL format: {video_url}")
        
        comments = downloader.get_comments(video_id)
        for comment in comments:
            all_comments.append({
                'Video_ID': video_id,
                'Comment': comment['text']
            })
    
    return all_comments

# %%
video_urls = [
    "https://youtu.be/K7PJZv5Johg?si=rRrZsCumvKFwjYsj",
    "https://youtu.be/Uccvf3peELQ?si=MuraPsCjHG--cl3w",
    "https://youtu.be/ubyErpdQAbs?si=GakOEkmMkW9uc2je",
    "https://youtu.be/Eq_okYibcGc?si=Nti7bjFcN8XpKoDs",
    "https://youtu.be/MOiTD_jwYvE?si=qdHOBfrBOzuit3ML"
]
comments = scrap_youtube_comments(video_urls)

# %%
len(comments)
# Out:
# 42203

# %%
comments
# Out:
# [{'Video_ID': 'K7PJZv5Johg', 'Comment': 'অসাধারণ  অসাধারণ ❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Who is watching in 2024...?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Nic gan❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'ai ganta amr onnek vlo lage❤ ar kar kar vlo lage...'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Brando Drive'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'কাল পরিক্ষা, এর মাঝে রাত ১১.৫৬ মিনিট হঠাৎ যে কেন এই গানটার কথা মনে পড়লো?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Audrey Trace'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '120'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😊😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Mon,16 sep.2024.... খোব ভালো লাগে গানটা❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গানটা যত শুনি তত ভালো লাগে❤️❤️'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '2024 সালে কারা কারা শুনছেন,, শুধু তারাই লাইক করবেন ❤️😌'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৪কে কে শুনেছেন লাইক করবেন'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'সুন্দর গান👌🥰❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '2024  eseo gan ta shunchi amar moto keke 2024 ei gan shuncho tarai shudu like diben'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024 keo acho naki 😢'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২৪ সালে কে কে দেখছেন ❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আমার মতো কে কে এই ২০২৪ এসে এই গান শুনতাছে,,তারা লাইক দিয়ে যাও❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Sister will looks'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Friesen Forks'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '২০১৮ সালে এই গানটি শুনি আজকে আবার  শুনলাম'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Willow Locks'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Rice Ramp'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😮❤❤😮❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Nice ❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Hillard Extensions'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Rm'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'দোয়া করি সবাই যেন সবার প্রিয় মানুষটারে পায়❤❤❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Mueller Pass'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Very nice .'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Roxanne Manors'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Bogan Center'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Skiles Station'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'So. Nice'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'এগুলো কে বলে মুভি 😊😊\nআর আমার সোনার ছেলেরা বা লের মুভি বানায়🥴'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': "I'm"},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Turner Garden'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমি  আছি'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'o..... Hey......  Shyam'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আমার প্রিয় মানুষটির প্রিয় গান \n২৫-০৫-২০২০  স্মৃতি হয়ে থাক।❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024 কে কে গান টা ছোনচো'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমি এ গানে নাচ করছি'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'মেয়ে মানুষ, মেয়ে মানুষের মত লাগবে। বর্তমান প্রজন্মের পরীমনি & পূজাচেরী বাদে কোনো নায়িকাকেই মেয়ে মনে হয়না।'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'So sweet song 🎵'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Super'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Ai sobi ke ke notun deksen. Ami suto belay dekesi'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এই ছবির নাম কী'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'একটা কমেন্ট  করেন রিপ্লাই দিব😊😊😊❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Collier Lake'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Amr favorite songs 😊'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '2024 sale aseo ganta sonte keno jani mon cay🙂'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Siyam r puja dujon ke amar anek valolage'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024a kk sunso like koro'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'কেন জানিনা গানটা শুনতে বলো লাগে মনের মতো একটি গান আমার মতো কার কার গানটা ভালো লাগে 😊😊😊😊😊😊😊❤❤❤❤❤🎉❤❤😊😊😅😅'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Nice ❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'After  long period of time.'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গান আমার অনেক প্রিয়❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Anyone in 2024?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024 SONG TA KE KE SUNCHO AMI'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমার পিয়'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আনেক সুন্দর  গান'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'অনেক দিন পর গান টার কথা মনে পরলো সুনতে আইলাম যদি কেউ কমেন্ট করে তবে আবার আসবো'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'সুন্দর হয়েছে'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Bangladesh গণতন্ত্রের নিয়ম অনুযায়ী জাতির পিতা বঙ্গবন্ধু,, ,, earth 🌎 দ্বীন ইসলাম নিয়ম অনুযায়ী জাতির পিতা ইব্রাহিম (আঃ),, অতএব তোমার দীন তোমার আমার দীন .. দ্বীন ইসলাম আল্লাহর পক্ষ থেকে কোরআন তাওরা / ., , বাকী সব দ্বীন ব্যবস্থা ইবলিস এর যেমন গনতন্ত্র ইত্যাদি'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'হাজার ও গানের মধ্যে একটি গান ❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আর।চাই নাকি চাই বলে'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'onkdin por ajk kn jani ganta sunte isse korlo🥹'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আজকে সৃতি রেখে গেলাম কমেন্ট করে'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'বিয়ের আগে শুনতাম। হৃদয় ছুয়ে যেত। এখন আর হৃদয় ছোয়না। প্রেম সুন্দর। সনিয়া,খুকুমণি, সানজিদা, লামিয়া সুন্দর।'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজ হঠাৎ গান টা শুনতে ইচ্ছে করলো কেনো❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'অসাধারণ'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '😔2030 সালের জন্য কমেন্ট করে গেলাম😰 আজ থেকে সাত বছর পর যখন ছুটরা কমেন্ট দেখবে 🥺তখন বুঝবে এই গান্টা আমাদের কতো প্রিয় ছিলো 😥😥'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024 সালের 26 এ আগষ্ট দেখতে আসলাম 😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'খুব  সুন্দর'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গানটা খুব সুন্দর'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'সিয়াম ভাই যেমনে উপরে সুন্দর ভেতরের মনটাও তেমন সুন্দর #বৈষ্বম্যবিরোধী_ছাত্র_আন্দোলন তার প্রমাণ ভালবাসা টা আরো বেড়ে গেল 🌺🥰'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'স্মৃতি রেখে গেলাম❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'পাগোল আমি ু'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'কিছু গান বাংলাদেশের গর্ব🥰শুনতে এতো ভালো লাগে ❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'So nice ❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'কোন এক জনের জন্য ২০১৯ সাল থেকে এই ছবির গান গুলো ভালো লাগে। \nnispup prem'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Hi'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আমি একজন ডানচার আমার কাছে 100বে\u200cশি মানুষ নাচ শিখতে আসে কিন্তু এই এই নাচের \nমত এত খারাপ নাচ এর আগে কখনো কেউ নাচেনি'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমি আছি ২০২৪.০৮.২৩ আজকে❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Love this song ( frm india , tn ) ❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤❤😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২৪ সালে কে কে শুনতে আসছেন??'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '২০২১ সালে যে কত শত বার এই গান টা শোনেছি আর কাদছি। তার কোন হিসাব নাই...'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '6 bochor por dekhlam abar.'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমার পছন্দ গান'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এই গান টা ৬ বছর আগে দেখে ছিলাম 😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'হুম ❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Onak,SundoraGanamarkuobvalolagasa🎉😊😊❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '১৯/৮/২০২৪ এই গানটা শুনতে আসলাম❤ গানটা অনেক ভাল লাগে পছন্দের একটা গান❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '২০১৯  সালে গানটা রিলিজ হওয়ার পর থেকে কত বার দেখছি হিসেব নেই'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Ai gan ta sunle amar x ar kotha mone pore'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজকে হঠাৎ করে গান টা শুনতে ইচ্ছা করলো কেন জানি না। 2024.8.17'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'r gp/lj'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'এই গান টা আমার প্রিয়ো মানুষ টার পছন্দ, সেই মানুষ টাই এখন আমার নায়, রেখে গিয়েছে গান টা 💔🥀😭'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Age ai gan gulo sunle nacte icce korto kintu akhon sudu ager sriti gulo sudu mone kori😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '৬ বছর আগে দেখছিলাম আজ ৬ বছর পর হটাট মনে পরলো ৬ বছর পর আবার দেখছি😢 ছোট বেলার প্রিয় গান এখনো😢 ২০২৪'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজকে হঠাৎ করে গান টা শুনতে ইচ্ছা করলো কেন জানি না 🙂'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤😂😂❤❤❤❤❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজকে হঠাৎ করে গানটা মনে পড়লো 14,8,2024'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজ হঠাৎ  কেনো গান টাকে এতো ভালো লাগলো  এক যায়গায় বসে ৫ বার শুনছি 😮'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤️❤️❤️❤️❤️❤️❤️🥰🥰'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Salman Sah Er Mrittur Por Amar Kache Bangladesher Etai Sera Movie....'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'অসাধারণ একটা গান শুনলেই মোন ভালো হয়ে য়ায়।'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এই গান টা খুব ভালো লাগে তাই'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এমনে'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'ওটার চবি দেও'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৪ সাকে কেউ শুনতে আসছেন??? \n😅'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'দেখা হবে নতুন কোন পরিবর্তন নিয়ে\n🙂 - ইনশাআল্লাহ - 🤲'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গান অনেক সুন্দর ❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'super song❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজকে গানটা শুনতে মন চায়তেছে যানি না কেন😊😊😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Kub sundor gaan'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'মুভি টা দেখে খারাপ লাগছিল 😊😢'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024 সালে এসে কে কে ােখে ছেন❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Sriti rekhe gelam 😊 poti bosore bosore shunbo 🥰😘'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Khub valobase falechi😢❤😢'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আল্লাহ সব মুমিমদের বুঝার তৈফিক দান করুক আমিন'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আর আমি ২০২৪ এ এসে আবারো দেখতে আসলাম,,'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '😊😊\n\n\n\nP\nP\n😊\n\nP\n😊\n\nPp\n 😊ppp\n\n\n\n\n\n\nPp😊😊😊\n\n\nP'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Dsgrdjt\n\n\n\n\n\n\n\n\n\nRy stuff'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Ehdrgd5xcccggtjy7fdt'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '2024সালে কমেন্ট টা করছি আবার2030, সালে কমেন্টটা দেখব❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '১২৩৪৫৬৭৮৯০)@'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😊❤😊😮'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '২০২৪সালে কে কে শুনছেন?\n\nএকটা লাইক দিয়ে যান🤩❤️'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এই গানটা আমার অনেক ভালো লাগে 😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৪'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Ko😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'সত্যিই গানটা সেই হয়েছে'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'অনেক অনেক শুভেচ্ছা❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2014 ❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '🥰🥰🥰🥰🥰🥰🥰'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'I🎉😢, the'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'I'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Ggzx'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Ame 2024'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'একদিন এই গানে আমি আর প্রিয় মানুষ টার সাথে  নাচবো 🙈'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤😊😊'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'এসব গান সুনলে প্রেম করার  ওনেক ইচ্চে হই। কিন্তু পুরা কপাল। কি করমু 😢😢😢'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'এই গান ও সিনেমা টায় অনেক স্মৃতি জড়িয়ে আছে তাই সিনেমা  এখনো রেখে দিছি মাঝে মধ্যে দেখি,, আসলে আমি তেমন সিনেমা দেখি না বাট পোড়ামন ২ সিনেমা টা যতই দেখি না ওদের প্রেম কাহিনি টা বার বার দেখতে মন চায় 😊💔'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Anyone 2025?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গানটা ভালো লাগে কেনো জানি'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Ai  ganer sathe amar durga pujar  ekta alade sriti  joriye ache  amar moto kar kar sriti  joriye comment karo takhan abar  ganta  sunbo'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'বেস্ট অফ রায়হান রাফি'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '২০১৮ তেই প্রথম শুনেছিলাম। যতদিন বেঁচে থাকবো ইচ্ছে হলেই এই গান শুনবো।'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'হঠাৎ কেন জানি গান টা শুনতে ইচ্ছে করছে তাই শুনছি❤🤩'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'https://youtu.be/qQzxIq2eV2E'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'https://youtube.com/shorts/z6Q6eAv7HlY?si=hA97FB44VoRs_F6b'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Right'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'kno jani mone porlo gan tar khotha aj'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2k24 anyone here🎉'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤২০২৪ সালে আবারও দেখতে আসলাম ❤❤❤❤❤😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '🤩🖤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'ইন্টারনেট আসার পর এই গানটা শুনতে এলাম'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Aj sunlam 2024.25 july'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2025 সে কে কে শুনবেন এই গান টা😀❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এই গানের ছবির নাম কি?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৪ সালের কেউ আছে নাকি'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমি ও'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'হে আমি  আছি❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আছিরে আছি'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': "I'm here."},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Achi'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'হুম'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আছিরে  ভইন আছি'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Hm mone porce tai suhte asolam'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'হুম😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Ami ace go❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Are... Achi re.. Favorite song chilo ache r thakbe😂'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমিও আছি🙋\u200d♂️🙋\u200d♂️❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '\xa0@MdRonikhan-q4j\xa0 amio asi go sona🙋\u200d♀️🙋\u200d♀️'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'নাইচ❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Beautiful'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গানটা আমার খুব ভালো লাগলো 😊😊😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2025 theke bolchi'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'সবাই লাইক করবেন।😢😢🙏🙏🙏🫵👍'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '"ওহে শ্যাম তোমারে আমি নয়নে নয়নে রাখিব অন্য কেউ রে না আমি চাইতে দিবো " একদিন আমিও কাউকে বলবো🥰'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'কে কে এখন ও গান টা শুনেন?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '117 million'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আমার গার্লফ্রেন্ডের পছন্দের গান এজন্য আমিও শুনি 😍'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024 keke deksen 👍👍❤️'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😂😂😂😂😂 হাই আই'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'ভালো লাগছে'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'নাটককেী নাম পুরামন ২'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': '২০২৪ সালে কে কে শুনছেন ?😊\nএকটা লাইক দিয়ে যান 👍'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': ',:/😅'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'মায়া লাগিয়ে ছেড়ে চলে গেছে'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'সেই সুন্দর গানটা ❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '11/7/2024'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজকে তারিখ 10.7.2024 কমেন্ট রেখে গেলাম আমি চলে জাবার পরেও জারা গানটা শুনতে আসতে তারা এই কমেন্ট টা দেখবে আর ভাববে কতো আগের যুগের গান টা ❤❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আমি এই মুভিটা টা রিলিজ হওয়ার পরেই দেখছি আরো ৬ বছর আগে আজকে হঠাও করে কেনো জানি গানটা শুনতে ইচ্ছা করলো তাই আবার চলে আসলাম ৬ বছর পরে সত্যি বলতে গানটা খুব ভালো লাগে ❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৪ সালে এসে  এই গান শুনলো কারা?'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '🤩🤩🤩🤩🤩🤩🤩'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'হাজারো গানে ভিরে গান টা অনেক ভালো লাগে 🥰'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '❤❤❤❤❤❤❤❤❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '😢❤'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৫ সালে কে কে শুনছো😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Movei tar nam ki'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'বাংলাদেশের সবথেকে সেরা গান ❤😊love from India ❤😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '২০২৪❤'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আজকে কেন জানিনা এই গানটা আমার চোখের সামনে আসলো দাদুর সাথে বসে বসে এই গানটি দেখতাম'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'এই মুভির নাম কি'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'আমার আজকে জন্মদিন তাই আমি এই গানটা 😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'আমি এই গানটা স্কুল এনেছি 😊😊😊😊'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Agan amer basi valo lagasa❤❤😂😂😂😂😂😂😂❤❤❤❤❤❤😂😂😂😂'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': '2024/6/6🎉🎉ke ke sunsen bole jaben'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'গানটা আমার কাসে ভালো লাগে'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Hii'},
#  {'Video_ID': 'K7PJZv5Johg', 'Comment': 'Rte'},
#  {'Video_ID': 'K7PJZv5Johg',
#   'Comment': 'Salman Sah Er Mrittur Por Amar Kache Bangladesher Etai Sera Movie....'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Anyone in September 2024😁😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Nice thanks univars'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Bangladesher Sunny Leone ❤️'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': '❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤😊😊😊😊❤😊❤❤😊😊❤😊❤😊❤😊❤😊❤😊❤😊❤😊❤😊😊😊❤😊❤😊❤😊❤😊❤😊😂😊😊❤😊😂😊❤😊😊😂😊😂😊😂😊😊❤😊😂😊😂😊😂😊😂😊😂😊😂😊😂😂❤❤❤😂😂'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😎😎😎'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'গান টা  অনেক সুন্দর ❤❤'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😊😊😊😊❤❤❤❤ ই'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': '❤❤😂😂😂😂😂❤❤❤❤❤❤❤😂😂❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤টটটটট'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Mamka AMRA SPECIALLY HLP KORBO.'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'আমি ডানা কাটা বুড়ি😂'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '🇦🇱🇦🇿🚩🚩🌈🏳️\u200d🌈🖲️🌹🎂'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': 'সাল ২০২৪ হঠাৎ রাত ১২ টায় পরির কথা মনে পড়লো তাই ইউটিউবে সার্চ করে গানটা শুনতে এলাম 😅'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2025 সালে কে কে এই গানটা শুনছেন 😊😊'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': 'Nice video play ❤🎉🎉❤🎉❤🎉❤🎉❤🎉❤🎉❤🎉🎉❤🎉❤🎉❤🎉❤😢😢😢😢😢'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😅😅😅😅\n😊😊😊'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😅😅'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😅😅'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😅😅😅😅😅😅'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': 'কেকে ইন্ডিয়া থেকে দেখছো হাত তুলো 🖐️🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳🇮🇳'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': 'Vai ki mongol groho thika bolsan...?'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'I❤u'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 
},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Kontho ta akdom  baby Nazniner moto'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'একটা নাড়া দিয়ে গেলাম ২০২৪ সালে'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 সালে কে কে গানটা শুনছেন😊🖤🫰'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'আমি সোনাকাটা পরী'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': '২০২৪ সালে এসে এখনো কে এই গান শোনেন \nসাড়া দিন 😊'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': '2024 এ এসে কে কে এই গান শুনছেন একটু রিপ্লাই দিয়ে যাবেন।। ধন্যবাদ'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 9 January 😂😂'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Still listening in 2024❤❤'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Bal kata pori🤣👈'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '২০২৪ সালে কে কে গানটা শুনছেন 🤩'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 সালে এসে কে কে গান টা শুনছেন'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 সালে আবার একবার শুনলাম ❤'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '২০২৪ সালে কে কে গানটা শুনছেন'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '২০২৪ 🎉🎉🎉'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '২০২৪ সালে কে কে সুনতেছ'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '২০২৪ সালে কে কে গান টা শুনতেছেন 😎'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 sale ke ke sunchen??❤❤'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': '২০২৪ এর জানুয়ারি! মা পরীকে দেখে আগের পরীকে দেখতে এলাম। কেমন একটা অবিশ্বাস্য পরিবর্তন! 💝💝'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '😁'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': 'MDWAHID how was the night are you too so beautiful💖💖💖💖💖💋💋💋👌👌👌🤗🤗🤗😱😱😱🎉🎉🎉2024'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': 'Thik amio boli ma howyar por koto mota hoye geche r koto change'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Hgdvzgxxxxw'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Tk%'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 sale ka ka ay gan ta daksan 😊'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '২০২৪ সালে কে কে গানটা শুনেছেন'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 a k k suncho'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 ❤😂🎉'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': '2024 k k sunteco'},
#  {'Video_ID': 'Uccvf3peELQ',
#   'Comment': '২০২৪ সালে কে  কে গানটা শুনতে এসেছেন 😁😁'},
#  {'Video_ID': 'Uccvf3peELQ', 'Comment': 'Love This song❤❤❤❤❤❤'},
#  ...]

# %%
import pandas as pd

comment_texts = [comment['Comment'] for comment in comments]
df = pd.DataFrame({'Comment': comment_texts})
df.head()
# Out:
#                                              Comment
# 0                                 অসাধারণ  অসাধারণ ❤
# 1                        Who is watching in 2024...?
# 2                                           Nic gan❤
# 3  ai ganta amr onnek vlo lage❤ ar kar kar vlo la...
# 4                                       Brando Drive

# %%
import re

def is_bangla(comment):
    bangla_regex = re.compile(r'^[\u0980-\u09FF\s]+$')
    return bool(bangla_regex.match(comment))

# %%
df = df[df['Comment'].apply(is_bangla)]
df.head()
# Out:
#                                       Comment
# 12               ২০২৪কে কে শুনেছেন লাইক করবেন
# 23  ২০১৮ সালে এই গানটি শুনি আজকে আবার  শুনলাম
# 40                                   আমি  আছি
# 44                        আমি এ গানে নাচ করছি
# 49                             এই ছবির নাম কী

# %%
df.drop_duplicates(inplace=True)

# %%
def count_words(comment):
    return len(comment.split())

# %%
df = df[df['Comment'].apply(count_words) >= 5]

# %%
df.head(50)
# Out:
#                                                Comment
# 12                        ২০২৪কে কে শুনেছেন লাইক করবেন
# 23           ২০১৮ সালে এই গানটি শুনি আজকে আবার  শুনলাম
# 44                                 আমি এ গানে নাচ করছি
# 66   অনেক দিন পর গান টার কথা মনে পরলো সুনতে আইলাম য...
# 73                     আজকে সৃতি রেখে গেলাম কমেন্ট করে
# 103  ২০১৯  সালে গানটা রিলিজ হওয়ার পর থেকে কত বার দে...
# 120                        এই গান টা খুব ভালো লাগে তাই
# 135       আল্লাহ সব মুমিমদের বুঝার তৈফিক দান করুক আমিন
# 163                          গানটা ভালো লাগে কেনো জানি
# 176              ইন্টারনেট আসার পর এই গানটা শুনতে এলাম
# 180                            ২০২৪ সালের কেউ আছে নাকি
# 212                       মায়া লাগিয়ে ছেড়ে চলে গেছে
# 227  আজকে কেন জানিনা এই গানটা আমার চোখের সামনে আসলো...
# 233                         গানটা আমার কাসে ভালো লাগে
# 267                               ঘরের লোক কয় মজা নিম
# 285                       কে কে জয়পুরহাট  থেকে  দেখছেন
# 301  এই ভিডিও দেখে যত মানুষ সুন্দর হওয়াও দেবে সব গ...
# 305                   তোরে সামনে দেখলে আমার ঘুম আসে না
# 404             মিম কে বলে পরীমনি কম ছোট ড্রেস পরে নাই
# 439               পরীমনির থেকে বিদেশি গুলো বেশি সুন্দর
# 488  করিনা কাপুরের গলায় পরিমনির পাঠ করা ডানা কাটা ...
# 512          দুষ্ট কুকিলের থেকে বেশি হিট ডানা কাটা পরি
# 515        পরির মাহির মতো আইটেম গানে আর কাওরে মানায় না
# 527         বাংলাদেশের সর্বকালের সর্বশ্রেষ্ঠ আইটেম গান
# 536                         কি বলেন আপনারা কেমন লেগেছে
# 556                    ঈদের ৭ দিন আগে কে কে দেখতে আসছো
# 571  তুই একটা পাগল তোর লজ্জা শরম নাই শয়তান কুত্তা ...
# 577              পাগল টানা না কাটা কাটার নাচতে পারে না
# 578                       ২০২৪ সালে কে কে গানটা শুনছেন
# 579  তোদের জদি লজ্জা শরম থাকতো উলঙ্গ হয়ে বেহায়ার ...
# 587                          পরিমনি আসলে ডানা কাটা পরি
# 594       মাহিয়া মাহি থাকলে আরো বেশি ভালো লাগতো গানটা
# 601                              এই গানের মুভির নাম কি
# 619  আমি  ২০২২সাল  থেকে   এটা   দেখে  আসছি  আর   এখ...
# 661  ২০২৪সালের এপ্রিল থেকে এখন পর্যন্ত কে কে এই গান...
# 677  এই গান আমি একটানা ২২ সুনছি  তাউ কেমন জানি মনো ...
# 728           আগামী তে আরো এরকম গান দেখতে পারব আশা করি
# 729                            আমার দেখা সেরা একটি গান
# 743      বাংলাদেশের দশ টা আইটেম গানের মধ্যে এই টা একটা
# 784         এই গানের ছবির নাম কি কেউ জানলে বলবেন প্লিজ
# 801                আমার কাছে ওরে প্রতিবন্ধি পরি মনে হয়
# 804                              পরি মনি হায়রে কি করবে
# 824  গানটা অসাধারণ নায়িকাও দারুণ শুধু অতিরিক্ত লাই...
# 826               আসিস  কি  চুটা  পেট  বেরে  করে  নাচে
# 900           পরিমনী বিশ্বজগত জননী  কারণ তার মন পবিত্র
# 909                           আমি নস্ট হয়ে শুনতে এসেছি
# 933                              এই গানের ছবিটা নাম কী
# 965                     একটা নাড়া দিয়ে গেলাম ২০২৪ সালে
# 978                             ২০২৪ সালে কে কে সুনতেছ
# 993                      ২০২৪ সালে কে কে গানটা শুনেছেন

# %%
from Levenshtein import ratio

comment_1 = "২০২৪ সালে কে কে সুনতেছ"
comment_2 = "২০২৪ সালে কে কে গানটা শুনেছেন"

similarity_ratio = ratio(comment_1, comment_2)
similarity_percentage = similarity_ratio * 100
print(f"Similarity: {similarity_percentage:.2f}%")
# Out:
# Similarity: 78.43%

# %%
def remove_similar_comments(df, threshold=0.6):
    indices_to_drop = set()
    
    for i in range(len(df)):
        if i in indices_to_drop:
            continue
        
        for j in range(i + 1, len(df)):
            if j in indices_to_drop:
                continue
            
            comment_1 = df.iloc[i]['Comment']
            comment_2 = df.iloc[j]['Comment']
            
            similarity = ratio(comment_1, comment_2)
            
            if similarity > threshold:
                indices_to_drop.add(j)
    
    valid_indices_to_drop = [idx for idx in indices_to_drop if idx in df.index]
    
    df = df.drop(index=valid_indices_to_drop).reset_index(drop=True)
    return df

# %%
df = remove_similar_comments(df)
df.head(10)
# Out:
#                                              Comment
# 0                       ২০২৪কে কে শুনেছেন লাইক করবেন
# 1          ২০১৮ সালে এই গানটি শুনি আজকে আবার  শুনলাম
# 2                                আমি এ গানে নাচ করছি
# 3  অনেক দিন পর গান টার কথা মনে পরলো সুনতে আইলাম য...
# 4                    আজকে সৃতি রেখে গেলাম কমেন্ট করে
# 5  ২০১৯  সালে গানটা রিলিজ হওয়ার পর থেকে কত বার দে...
# 6                        এই গান টা খুব ভালো লাগে তাই
# 7       আল্লাহ সব মুমিমদের বুঝার তৈফিক দান করুক আমিন
# 8                          গানটা ভালো লাগে কেনো জানি
# 9              ইন্টারনেট আসার পর এই গানটা শুনতে এলাম

# %%
religious_keywords = ['আল্লাহ', 'আমিন', 'ইনশাআল্লাহ', 'আল্লাহু', 'আকবর', 'মুমিম']

def remove_religious_comments(df, keywords):
    df_filtered = df[~df['Comment'].apply(lambda x: any(word in x for word in keywords))].reset_index(drop=True)
    return df_filtered

# %%
df = remove_religious_comments(df, religious_keywords)

# %%
def clean_text(text):
    cleaned_text = ' '.join(text.replace('\n', ' ').split())
    return cleaned_text

# %%
df['Comment'] = df['Comment'].apply(clean_text)

# %%
len(df)
# Out:
# 1771

# %%
df.head(10)
# Out:
#                                              Comment
# 0                       ২০২৪কে কে শুনেছেন লাইক করবেন
# 1           ২০১৮ সালে এই গানটি শুনি আজকে আবার শুনলাম
# 2                                আমি এ গানে নাচ করছি
# 3  অনেক দিন পর গান টার কথা মনে পরলো সুনতে আইলাম য...
# 4                    আজকে সৃতি রেখে গেলাম কমেন্ট করে
# 5  ২০১৯ সালে গানটা রিলিজ হওয়ার পর থেকে কত বার দেখ...
# 6                        এই গান টা খুব ভালো লাগে তাই
# 7                          গানটা ভালো লাগে কেনো জানি
# 8              ইন্টারনেট আসার পর এই গানটা শুনতে এলাম
# 9                       মায়া লাগিয়ে ছেড়ে চলে গেছে

# %%
df.to_csv("BengaliSent.csv", index=False)
